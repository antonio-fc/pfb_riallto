# %%
import npu
import numpy as np
from npu.build.appbuilder import AppBuilder
from npu.runtime import AppRunner
from npu.build.kernel import Kernel
import pylab as plt
import scipy

# %%
M     = 3          # Number of taps
P     = 16       # Number of 'branches', also fft length
W     = 1024       # Number of windows of length M*P in input time stream
n_int = 10          # Number of time integrations on output data
n_points=M*P
dt=np.complex64

# %%
def createKernel(kernel_name):
    kernel_path = f"./kernels/{kernel_name}.c"
    with open(kernel_path, 'r') as file:
        data = file.read()
    get_ipython().run_cell_magic('kernel', '', data)

def generateKernels(W, M, P, dt):
    # Frontend kernel
    createKernel("fft")
    fft_kernel.ports[0].array = np.ndarray([1, P], dtype=np.uint64)
    fft_kernel.ports[1].array = np.ndarray([1, P], dtype=np.uint64)
    fft_kernel.ports[2].array = np.ndarray([1, P], dtype=np.uint64)

    return [fft_kernel]

# %%
kernels = generateKernels(W, M, P, dt)

# %%
class SimpleApplication(AppBuilder):
    
    def __init__(self, kernels):
        self.frontend = kernels[0]
        super().__init__()

    def callgraph(self, x_in:np.ndarray, x_in2:np.ndarray, x_out:np.ndarray):
        rows = x_in.shape[0]
        size = x_in.shape[1]
        for row in range(rows):
            kernel_output = self.frontend(x_in[row], x_in2[row], size)
            x_out[row] = kernel_output

# %%
# Making the app
app_builder = SimpleApplication(kernels)

# Building the app
input_form = np.zeros(shape=(1, P), dtype=np.uint64)
input_form2 = np.zeros(shape=(1, P), dtype=np.uint64)
output_form = np.zeros(shape=(1, P), dtype=np.uint64)

app_builder.build(input_form, input_form2, output_form)

app = AppRunner('SimpleApplication.xclbin')
# Out:
# Building the fft_kernel kernel...
# ERROR! WSL failed
#
# RTNETLINK answers: File exists
# In file included from fft_kernel.cc:8:
# In file included from /opt/tools/Vitis/2023.1/aietools/include/aie_api/aie.hpp:85:
# In file included from /opt/tools/Vitis/2023.1/aietools/include/aie_api/detail/abs.hpp:103:
# In file included from /opt/tools/Vitis/2023.1/aietools/include/aie_api/detail/aie2/abs.hpp:54:
# In file included from /opt/tools/Vitis/2023.1/aietools/include/aie_api/detail/aie2/../broadcast.hpp:196:
# /opt/tools/Vitis/2023.1/aietools/include/aie_api/detail/aie2/broadcast.hpp:213:77: warning: 'clr32' is deprecated: Function 'clr' is deprecated. Please use the 'broadcast_zero_to' variant instead. [-Wdeprecated-declarations]
#             if constexpr (Class == AccumClass::Int)  return []() { return ::clr32();  };
#                                                                             ^
# /opt/tools/Vitis/2023.1/aietools/data/aie_ml/lib/isg/me_chess_llvm.h:112034:7: note: 'clr32' has been explicitly marked deprecated here
#     [[deprecated("Function 'clr' is deprecated. Please use the 'broadcast_zero_to' variant instead.")]] inline __attribute__((always_inline)) v32acc32 clr32(void) __attribute__((overloadable))
#       ^
# In file included from fft_kernel.cc:8:
# In file included from /opt/tools/Vitis/2023.1/aietools/include/aie_api/aie.hpp:85:
# In file included from /opt/tools/Vitis/2023.1/aietools/include/aie_api/detail/abs.hpp:103:
# In file included from /opt/tools/Vitis/2023.1/aietools/include/aie_api/detail/aie2/abs.hpp:54:
# In file included from /opt/tools/Vitis/2023.1/aietools/include/aie_api/detail/aie2/../broadcast.hpp:196:
# /opt/tools/Vitis/2023.1/aietools/include/aie_api/detail/aie2/broadcast.hpp:214:77: warning: 'clr16c' is deprecated: Function 'clr' is deprecated. Please use the 'broadcast_zero_to' variant instead. [-Wdeprecated-declarations]
#             if constexpr (Class == AccumClass::CInt) return []() { return ::clr16c();  };
#                                                                             ^
# /opt/tools/Vitis/2023.1/aietools/data/aie_ml/lib/isg/me_chess_llvm.h:112232:7: note: 'clr16c' has been explicitly marked deprecated here
#     [[deprecated("Function 'clr' is deprecated. Please use the 'broadcast_zero_to' variant instead.")]] inline __attribute__((always_inline)) v8cacc64 clr16c(void) __attribute__((overloadable))
#       ^
# In file included from fft_kernel.cc:8:
# In file included from /opt/tools/Vitis/2023.1/aietools/include/aie_api/aie.hpp:85:
# In file included from /opt/tools/Vitis/2023.1/aietools/include/aie_api/detail/abs.hpp:103:
# In file included from /opt/tools/Vitis/2023.1/aietools/include/aie_api/detail/aie2/abs.hpp:54:
# In file included from /opt/tools/Vitis/2023.1/aietools/include/aie_api/detail/aie2/../broadcast.hpp:196:
# /opt/tools/Vitis/2023.1/aietools/include/aie_api/detail/aie2/broadcast.hpp:215:77: warning: 'clr16f' is deprecated: Function 'clr' is deprecated. Please use the 'broadcast_zero_to' variant instead. [-Wdeprecated-declarations]
#             if constexpr (Class == AccumClass::FP)   return []() { return ::clr16f(); };
#                                                                             ^
# /opt/tools/Vitis/2023.1/aietools/data/aie_ml/lib/isg/me_chess_llvm.h:112331:7: note: 'clr16f' has been explicitly marked deprecated here
#     [[deprecated("Function 'clr' is deprecated. Please use the 'broadcast_zero_to' variant instead.")]] inline __attribute__((always_inline)) v16accfloat clr16f(void) __attribute__((overloadable))
#       ^
# In file included from fft_kernel.cc:8:
# In file included from /opt/tools/Vitis/2023.1/aietools/include/aie_api/aie.hpp:85:
# In file included from /opt/tools/Vitis/2023.1/aietools/include/aie_api/detail/abs.hpp:103:
# In file included from /opt/tools/Vitis/2023.1/aietools/include/aie_api/detail/aie2/abs.hpp:54:
# In file included from /opt/tools/Vitis/2023.1/aietools/include/aie_api/detail/aie2/../broadcast.hpp:196:
# /opt/tools/Vitis/2023.1/aietools/include/aie_api/detail/aie2/broadcast.hpp:218:77: warning: 'clr16' is deprecated: Function 'clr' is deprecated. Please use the 'broadcast_zero_to' variant instead. [-Wdeprecated-declarations]
#             if constexpr (Class == AccumClass::Int)  return []() { return ::clr16();  };
#                                                                             ^
# /opt/tools/Vitis/2023.1/aietools/data/aie_ml/lib/isg/me_chess_llvm.h:112133:7: note: 'clr16' has been explicitly marked deprecated here
#     [[deprecated("Function 'clr' is deprecated. Please use the 'broadcast_zero_to' variant instead.")]] inline __attribute__((always_inline)) v16acc64 clr16(void) __attribute__((overloadable))
#       ^
# In file included from fft_kernel.cc:8:
# In file included from /opt/tools/Vitis/2023.1/aietools/include/aie_api/aie.hpp:85:
# In file included from /opt/tools/Vitis/2023.1/aietools/include/aie_api/detail/abs.hpp:103:
# In file included from /opt/tools/Vitis/2023.1/aietools/include/aie_api/detail/aie2/abs.hpp:54:
# In file included from /opt/tools/Vitis/2023.1/aietools/include/aie_api/detail/aie2/../broadcast.hpp:196:
# /opt/tools/Vitis/2023.1/aietools/include/aie_api/detail/aie2/broadcast.hpp:219:77: warning: 'clr16c' is deprecated: Function 'clr' is deprecated. Please use the 'broadcast_zero_to' variant instead. [-Wdeprecated-declarations]
#             if constexpr (Class == AccumClass::CInt) return []() { return ::clr16c();  };
#                                                                             ^
# /opt/tools/Vitis/2023.1/aietools/data/aie_ml/lib/isg/me_chess_llvm.h:112232:7: note: 'clr16c' has been explicitly marked deprecated here
#     [[deprecated("Function 'clr' is deprecated. Please use the 'broadcast_zero_to' variant instead.")]] inline __attribute__((always_inline)) v8cacc64 clr16c(void) __attribute__((overloadable))
#       ^
# In file included from fft_kernel.cc:8:
# In file included from /opt/tools/Vitis/2023.1/aietools/include/aie_api/aie.hpp:92:
# In file included from /opt/tools/Vitis/2023.1/aietools/include/aie_api/detail/compare.hpp:289:
# /opt/tools/Vitis/2023.1/aietools/include/aie_api/detail/aie2/compare.hpp:200:52: warning: 'clr16f' is deprecated: Function 'clr' is deprecated. Please use the 'broadcast_zero_to' variant instead. [-Wdeprecated-declarations]
#             accum<AccumClass::FP, 32, 16> zero = ::clr16f();
#                                                    ^
# /opt/tools/Vitis/2023.1/aietools/data/aie_ml/lib/isg/me_chess_llvm.h:112331:7: note: 'clr16f' has been explicitly marked deprecated here
#     [[deprecated("Function 'clr' is deprecated. Please use the 'broadcast_zero_to' variant instead.")]] inline __attribute__((always_inline)) v16accfloat clr16f(void) __attribute__((overloadable))
#       ^
# In file included from fft_kernel.cc:8:
# In file included from /opt/tools/Vitis/2023.1/aietools/include/aie_api/aie.hpp:92:
# In file included from /opt/tools/Vitis/2023.1/aietools/include/aie_api/detail/compare.hpp:289:
# /opt/tools/Vitis/2023.1/aietools/include/aie_api/detail/aie2/compare.hpp:214:52: warning: 'clr16f' is deprecated: Function 'clr' is deprecated. Please use the 'broadcast_zero_to' variant instead. [-Wdeprecated-declarations]
#             accum<AccumClass::FP, 32, 16> zero = ::clr16f();
#                                                    ^
# /opt/tools/Vitis/2023.1/aietools/data/aie_ml/lib/isg/me_chess_llvm.h:112331:7: note: 'clr16f' has been explicitly marked deprecated here
#     [[deprecated("Function 'clr' is deprecated. Please use the 'broadcast_zero_to' variant instead.")]] inline __attribute__((always_inline)) v16accfloat clr16f(void) __attribute__((overloadable))
#       ^
# In file included from fft_kernel.cc:8:
# In file included from /opt/tools/Vitis/2023.1/aietools/include/aie_api/aie.hpp:92:
# In file included from /opt/tools/Vitis/2023.1/aietools/include/aie_api/detail/compare.hpp:289:
# /opt/tools/Vitis/2023.1/aietools/include/aie_api/detail/aie2/compare.hpp:225:52: warning: 'clr16f' is deprecated: Function 'clr' is deprecated. Please use the 'broadcast_zero_to' variant instead. [-Wdeprecated-declarations]
#             accum<AccumClass::FP, 32, 16> zero = ::clr16f();
#                                                    ^
# /opt/tools/Vitis/2023.1/aietools/data/aie_ml/lib/isg/me_chess_llvm.h:112331:7: note: 'clr16f' has been explicitly marked deprecated here
#     [[deprecated("Function 'clr' is deprecated. Please use the 'broadcast_zero_to' variant instead.")]] inline __attribute__((always_inline)) v16accfloat clr16f(void) __attribute__((overloadable))
#       ^
# In file included from fft_kernel.cc:8:
# In file included from /opt/tools/Vitis/2023.1/aietools/include/aie_api/aie.hpp:95:
# In file included from /opt/tools/Vitis/2023.1/aietools/include/aie_api/detail/fft.hpp:509:
# In file included from /opt/tools/Vitis/2023.1/aietools/include/aie_api/detail/aie2/fft_dit.hpp:67:
# /opt/tools/Vitis/2023.1/aietools/include/aie_api/detail/aie2/fft_dit_radix2.hpp:154:14: warning: 'broadcast_zero_c16' is deprecated: Function 'broadcast_zero_c16' is deprecated. Please use the 'broadcast_zero_to_v16cint16' variant instead. [-Wdeprecated-declarations]
#     { c_ = ::broadcast_zero_c16(); }
#              ^
# /opt/tools/Vitis/2023.1/aietools/data/aie_ml/lib/isg/me_chess_llvm.h:76301:7: note: 'broadcast_zero_c16' has been explicitly marked deprecated here
#     [[deprecated("Function 'broadcast_zero_c16' is deprecated. Please use the 'broadcast_zero_to_v16cint16' variant instead.")]] inline __attribute__((always_inline)) v16cint16 broadcast_zero_c16(void) __attribute__((overloadable))
#       ^
# In file included from fft_kernel.cc:8:
# In file included from /opt/tools/Vitis/2023.1/aietools/include/aie_api/aie.hpp:95:
# In file included from /opt/tools/Vitis/2023.1/aietools/include/aie_api/detail/fft.hpp:509:
# In file included from /opt/tools/Vitis/2023.1/aietools/include/aie_api/detail/aie2/fft_dit.hpp:67:
# /opt/tools/Vitis/2023.1/aietools/include/aie_api/detail/aie2/fft_dit_radix2.hpp:253:20: warning: 'clr16c' is deprecated: Function 'clr' is deprecated. Please use the 'broadcast_zero_to' variant instead. [-Wdeprecated-declarations]
#         zeros_ = ::clr16c();
#                    ^
# /opt/tools/Vitis/2023.1/aietools/data/aie_ml/lib/isg/me_chess_llvm.h:112232:7: note: 'clr16c' has been explicitly marked deprecated here
#     [[deprecated("Function 'clr' is deprecated. Please use the 'broadcast_zero_to' variant instead.")]] inline __attribute__((always_inline)) v8cacc64 clr16c(void) __attribute__((overloadable))
#       ^
# In file included from fft_kernel.cc:8:
# In file included from /opt/tools/Vitis/2023.1/aietools/include/aie_api/aie.hpp:95:
# In file included from /opt/tools/Vitis/2023.1/aietools/include/aie_api/detail/fft.hpp:509:
# In file included from /opt/tools/Vitis/2023.1/aietools/include/aie_api/detail/aie2/fft_dit.hpp:67:
# /opt/tools/Vitis/2023.1/aietools/include/aie_api/detail/aie2/fft_dit_radix2.hpp:254:16: warning: 'broadcast_zero_c16' is deprecated: Function 'broadcast_zero_c16' is deprecated. Please use the 'broadcast_zero_to_v16cint16' variant instead. [-Wdeprecated-declarations]
#         c_ = ::broadcast_zero_c16();
#                ^
# /opt/tools/Vitis/2023.1/aietools/data/aie_ml/lib/isg/me_chess_llvm.h:76301:7: note: 'broadcast_zero_c16' has been explicitly marked deprecated here
#     [[deprecated("Function 'broadcast_zero_c16' is deprecated. Please use the 'broadcast_zero_to_v16cint16' variant instead.")]] inline __attribute__((always_inline)) v16cint16 broadcast_zero_c16(void) __attribute__((overloadable))
#       ^
# In file included from fft_kernel.cc:8:
# In file included from /opt/tools/Vitis/2023.1/aietools/include/aie_api/aie.hpp:95:
# In file included from /opt/tools/Vitis/2023.1/aietools/include/aie_api/detail/fft.hpp:509:
# In file included from /opt/tools/Vitis/2023.1/aietools/include/aie_api/detail/aie2/fft_dit.hpp:67:
# /opt/tools/Vitis/2023.1/aietools/include/aie_api/detail/aie2/fft_dit_radix2.hpp:330:30: warning: 'broadcast_zero_c16' is deprecated: Function 'broadcast_zero_c16' is deprecated. Please use the 'broadcast_zero_to_v16cint16' variant instead. [-Wdeprecated-declarations]
#         c_ = ::shuffle(d0, ::broadcast_zero_c16(), T64_8x2_hi);
#                              ^
# /opt/tools/Vitis/2023.1/aietools/data/aie_ml/lib/isg/me_chess_llvm.h:76301:7: note: 'broadcast_zero_c16' has been explicitly marked deprecated here
#     [[deprecated("Function 'broadcast_zero_c16' is deprecated. Please use the 'broadcast_zero_to_v16cint16' variant instead.")]] inline __attribute__((always_inline)) v16cint16 broadcast_zero_c16(void) __attribute__((overloadable))
#       ^
# In file included from fft_kernel.cc:8:
# In file included from /opt/tools/Vitis/2023.1/aietools/include/aie_api/aie.hpp:95:
# In file included from /opt/tools/Vitis/2023.1/aietools/include/aie_api/detail/fft.hpp:509:
# In file included from /opt/tools/Vitis/2023.1/aietools/include/aie_api/detail/aie2/fft_dit.hpp:67:
# /opt/tools/Vitis/2023.1/aietools/include/aie_api/detail/aie2/fft_dit_radix2.hpp:331:48: warning: 'broadcast_zero_c16' is deprecated: Function 'broadcast_zero_c16' is deprecated. Please use the 'broadcast_zero_to_v16cint16' variant instead. [-Wdeprecated-declarations]
#         a = ::extract_v8cint16(::shuffle(d0, ::broadcast_zero_c16(), T64_8x2_lo), 0);
#                                                ^
# /opt/tools/Vitis/2023.1/aietools/data/aie_ml/lib/isg/me_chess_llvm.h:76301:7: note: 'broadcast_zero_c16' has been explicitly marked deprecated here
#     [[deprecated("Function 'broadcast_zero_c16' is deprecated. Please use the 'broadcast_zero_to_v16cint16' variant instead.")]] inline __attribute__((always_inline)) v16cint16 broadcast_zero_c16(void) __attribute__((overloadable))
#       ^
# In file included from fft_kernel.cc:8:
# In file included from /opt/tools/Vitis/2023.1/aietools/include/aie_api/aie.hpp:95:
# In file included from /opt/tools/Vitis/2023.1/aietools/include/aie_api/detail/fft.hpp:509:
# In file included from /opt/tools/Vitis/2023.1/aietools/include/aie_api/detail/aie2/fft_dit.hpp:67:
# /opt/tools/Vitis/2023.1/aietools/include/aie_api/detail/aie2/fft_dit_radix2.hpp:346:14: warning: 'broadcast_zero_c16' is deprecated: Function 'broadcast_zero_c16' is deprecated. Please use the 'broadcast_zero_to_v16cint16' variant instead. [-Wdeprecated-declarations]
#     { c_ = ::broadcast_zero_c16(); }
#              ^
# /opt/tools/Vitis/2023.1/aietools/data/aie_ml/lib/isg/me_chess_llvm.h:76301:7: note: 'broadcast_zero_c16' has been explicitly marked deprecated here
#     [[deprecated("Function 'broadcast_zero_c16' is deprecated. Please use the 'broadcast_zero_to_v16cint16' variant instead.")]] inline __attribute__((always_inline)) v16cint16 broadcast_zero_c16(void) __attribute__((overloadable))
#       ^
# In file included from fft_kernel.cc:8:
# In file included from /opt/tools/Vitis/2023.1/aietools/include/aie_api/aie.hpp:95:
# In file included from /opt/tools/Vitis/2023.1/aietools/include/aie_api/detail/fft.hpp:509:
# In file included from /opt/tools/Vitis/2023.1/aietools/include/aie_api/detail/aie2/fft_dit.hpp:67:
# /opt/tools/Vitis/2023.1/aietools/include/aie_api/detail/aie2/fft_dit_radix2.hpp:422:30: warning: 'broadcast_zero_c16' is deprecated: Function 'broadcast_zero_c16' is deprecated. Please use the 'broadcast_zero_to_v16cint16' variant instead. [-Wdeprecated-declarations]
#         c_ = ::shuffle(d0, ::broadcast_zero_c16(), T32_16x2_hi);
#                              ^
# /opt/tools/Vitis/2023.1/aietools/data/aie_ml/lib/isg/me_chess_llvm.h:76301:7: note: 'broadcast_zero_c16' has been explicitly marked deprecated here
#     [[deprecated("Function 'broadcast_zero_c16' is deprecated. Please use the 'broadcast_zero_to_v16cint16' variant instead.")]] inline __attribute__((always_inline)) v16cint16 broadcast_zero_c16(void) __attribute__((overloadable))
#       ^
# In file included from fft_kernel.cc:8:
# In file included from /opt/tools/Vitis/2023.1/aietools/include/aie_api/aie.hpp:95:
# In file included from /opt/tools/Vitis/2023.1/aietools/include/aie_api/detail/fft.hpp:509:
# In file included from /opt/tools/Vitis/2023.1/aietools/include/aie_api/detail/aie2/fft_dit.hpp:67:
# /opt/tools/Vitis/2023.1/aietools/include/aie_api/detail/aie2/fft_dit_radix2.hpp:423:48: warning: 'broadcast_zero_c16' is deprecated: Function 'broadcast_zero_c16' is deprecated. Please use the 'broadcast_zero_to_v16cint16' variant instead. [-Wdeprecated-declarations]
#         a = ::extract_v8cint16(::shuffle(d0, ::broadcast_zero_c16(), T32_16x2_lo), 0);
#                                                ^
# /opt/tools/Vitis/2023.1/aietools/data/aie_ml/lib/isg/me_chess_llvm.h:76301:7: note: 'broadcast_zero_c16' has been explicitly marked deprecated here
#     [[deprecated("Function 'broadcast_zero_c16' is deprecated. Please use the 'broadcast_zero_to_v16cint16' variant instead.")]] inline __attribute__((always_inline)) v16cint16 broadcast_zero_c16(void) __attribute__((overloadable))
#       ^
# In file included from fft_kernel.cc:8:
# In file included from /opt/tools/Vitis/2023.1/aietools/include/aie_api/aie.hpp:95:
# In file included from /opt/tools/Vitis/2023.1/aietools/include/aie_api/detail/fft.hpp:509:
# In file included from /opt/tools/Vitis/2023.1/aietools/include/aie_api/detail/aie2/fft_dit.hpp:67:
# /opt/tools/Vitis/2023.1/aietools/include/aie_api/detail/aie2/fft_dit_radix2.hpp:437:14: warning: 'broadcast_zero_c16' is deprecated: Function 'broadcast_zero_c16' is deprecated. Please use the 'broadcast_zero_to_v16cint16' variant instead. [-Wdeprecated-declarations]
#     { c_ = ::broadcast_zero_c16(); }
#              ^
# /opt/tools/Vitis/2023.1/aietools/data/aie_ml/lib/isg/me_chess_llvm.h:76301:7: note: 'broadcast_zero_c16' has been explicitly marked deprecated here
#     [[deprecated("Function 'broadcast_zero_c16' is deprecated. Please use the 'broadcast_zero_to_v16cint16' variant instead.")]] inline __attribute__((always_inline)) v16cint16 broadcast_zero_c16(void) __attribute__((overloadable))
#       ^
# In file included from fft_kernel.cc:8:
# In file included from /opt/tools/Vitis/2023.1/aietools/include/aie_api/aie.hpp:95:
# In file included from /opt/tools/Vitis/2023.1/aietools/include/aie_api/detail/fft.hpp:509:
# In file included from /opt/tools/Vitis/2023.1/aietools/include/aie_api/detail/aie2/fft_dit.hpp:68:
# /opt/tools/Vitis/2023.1/aietools/include/aie_api/detail/aie2/fft_dit_radix4.hpp:194:14: warning: 'broadcast_zero_c16' is deprecated: Function 'broadcast_zero_c16' is deprecated. Please use the 'broadcast_zero_to_v16cint16' variant instead. [-Wdeprecated-declarations]
#     { c_ = ::broadcast_zero_c16();
#              ^
# /opt/tools/Vitis/2023.1/aietools/data/aie_ml/lib/isg/me_chess_llvm.h:76301:7: note: 'broadcast_zero_c16' has been explicitly marked deprecated here
#     [[deprecated("Function 'broadcast_zero_c16' is deprecated. Please use the 'broadcast_zero_to_v16cint16' variant instead.")]] inline __attribute__((always_inline)) v16cint16 broadcast_zero_c16(void) __attribute__((overloadable))
#       ^
# In file included from fft_kernel.cc:8:
# In file included from /opt/tools/Vitis/2023.1/aietools/include/aie_api/aie.hpp:95:
# In file included from /opt/tools/Vitis/2023.1/aietools/include/aie_api/detail/fft.hpp:509:
# In file included from /opt/tools/Vitis/2023.1/aietools/include/aie_api/detail/aie2/fft_dit.hpp:68:
# /opt/tools/Vitis/2023.1/aietools/include/aie_api/detail/aie2/fft_dit_radix4.hpp:429:17: warning: 'broadcast_zero_c16' is deprecated: Function 'broadcast_zero_c16' is deprecated. Please use the 'broadcast_zero_to_v16cint16' variant instead. [-Wdeprecated-declarations]
#         w2_ = ::broadcast_zero_c16();
#                 ^
# /opt/tools/Vitis/2023.1/aietools/data/aie_ml/lib/isg/me_chess_llvm.h:76301:7: note: 'broadcast_zero_c16' has been explicitly marked deprecated here
#     [[deprecated("Function 'broadcast_zero_c16' is deprecated. Please use the 'broadcast_zero_to_v16cint16' variant instead.")]] inline __attribute__((always_inline)) v16cint16 broadcast_zero_c16(void) __attribute__((overloadable))
#       ^
# In file included from fft_kernel.cc:8:
# In file included from /opt/tools/Vitis/2023.1/aietools/include/aie_api/aie.hpp:99:
# In file included from /opt/tools/Vitis/2023.1/aietools/include/aie_api/detail/max_min.hpp:292:
# /opt/tools/Vitis/2023.1/aietools/include/aie_api/detail/aie2/max_min.hpp:247:27: warning: 'broadcast_zero_bfloat16' is deprecated: Function 'broadcast_zero_bfloat16' is deprecated. Please use the 'broadcast_zero_to_v32bfloat16' variant instead. [-Wdeprecated-declarations]
#             tmp = ::sel(::broadcast_zero_bfloat16(), sub<bfloat16, 32>::run(v1.template grow<32>(), v2.template grow<32>()), cmp);
#                           ^
# /opt/tools/Vitis/2023.1/aietools/data/aie_ml/lib/isg/me_chess_llvm.h:76315:7: note: 'broadcast_zero_bfloat16' has been explicitly marked deprecated here
#     [[deprecated("Function 'broadcast_zero_bfloat16' is deprecated. Please use the 'broadcast_zero_to_v32bfloat16' variant instead.")]] inline __attribute__((always_inline)) v32bfloat16 broadcast_zero_bfloat16(void) __attribute__((overloadable))
#       ^
# In file included from fft_kernel.cc:8:
# In file included from /opt/tools/Vitis/2023.1/aietools/include/aie_api/aie.hpp:99:
# In file included from /opt/tools/Vitis/2023.1/aietools/include/aie_api/detail/max_min.hpp:292:
# /opt/tools/Vitis/2023.1/aietools/include/aie_api/detail/aie2/max_min.hpp:308:27: warning: 'broadcast_zero_float' is deprecated: Function 'broadcast_zero_float' is deprecated. Please use the 'broadcast_zero_to_v16float' variant instead. [-Wdeprecated-declarations]
#             tmp = ::sel(::broadcast_zero_float(), sub<float, 16>::run(v1.template grow<16>(), v2.template grow<16>()), cmp);
#                           ^
# /opt/tools/Vitis/2023.1/aietools/data/aie_ml/lib/isg/me_chess_llvm.h:76322:7: note: 'broadcast_zero_float' has been explicitly marked deprecated here
#     [[deprecated("Function 'broadcast_zero_float' is deprecated. Please use the 'broadcast_zero_to_v16float' variant instead.")]] inline __attribute__((always_inline)) v16float broadcast_zero_float(void) __attribute__((overloadable))
#       ^
# In file included from fft_kernel.cc:8:
# In file included from /opt/tools/Vitis/2023.1/aietools/include/aie_api/aie.hpp:111:
# In file included from /opt/tools/Vitis/2023.1/aietools/include/aie_api/detail/linear_approx.hpp:66:
# /opt/tools/Vitis/2023.1/aietools/include/aie_api/detail/aie2/linear_approx.hpp:116:59: warning: 'broadcast_zero_u8' is deprecated: Function 'broadcast_zero_u8' is deprecated. Please use the 'broadcast_zero_to_v64uint8' variant instead. [-Wdeprecated-declarations]
#         rem_mask_vec_ = ::sel(::broadcast_u8(rem_mask), ::broadcast_zero_u8(), 0xFFFFFFFF00000000);
#                                                           ^
# /opt/tools/Vitis/2023.1/aietools/data/aie_ml/lib/isg/me_chess_llvm.h:76280:7: note: 'broadcast_zero_u8' has been explicitly marked deprecated here
#     [[deprecated("Function 'broadcast_zero_u8' is deprecated. Please use the 'broadcast_zero_to_v64uint8' variant instead.")]] inline __attribute__((always_inline)) v64uint8 broadcast_zero_u8(void) __attribute__((overloadable))
#       ^
# In file included from fft_kernel.cc:8:
# In file included from /opt/tools/Vitis/2023.1/aietools/include/aie_api/aie.hpp:111:
# In file included from /opt/tools/Vitis/2023.1/aietools/include/aie_api/detail/linear_approx.hpp:66:
# /opt/tools/Vitis/2023.1/aietools/include/aie_api/detail/aie2/linear_approx.hpp:235:60: warning: 'broadcast_zero_u16' is deprecated: Function 'broadcast_zero_u16' is deprecated. Please use the 'broadcast_zero_to_v32uint16' variant instead. [-Wdeprecated-declarations]
#         rem_mask_vec_ = ::sel(::broadcast_u16(rem_mask), ::broadcast_zero_u16(), 0xFFFF0000);
#                                                            ^
# /opt/tools/Vitis/2023.1/aietools/data/aie_ml/lib/isg/me_chess_llvm.h:76287:7: note: 'broadcast_zero_u16' has been explicitly marked deprecated here
#     [[deprecated("Function 'broadcast_zero_u16' is deprecated. Please use the 'broadcast_zero_to_v32uint16' variant instead.")]] inline __attribute__((always_inline)) v32uint16 broadcast_zero_u16(void) __attribute__((overloadable))
#       ^
# In file included from fft_kernel.cc:8:
# In file included from /opt/tools/Vitis/2023.1/aietools/include/aie_api/aie.hpp:111:
# In file included from /opt/tools/Vitis/2023.1/aietools/include/aie_api/detail/linear_approx.hpp:66:
# /opt/tools/Vitis/2023.1/aietools/include/aie_api/detail/aie2/linear_approx.hpp:236:27: warning: 'broadcast_zero_u16' is deprecated: Function 'broadcast_zero_u16' is deprecated. Please use the 'broadcast_zero_to_v32uint16' variant instead. [-Wdeprecated-declarations]
#         rem_vec_      = ::broadcast_zero_u16();
#                           ^
# /opt/tools/Vitis/2023.1/aietools/data/aie_ml/lib/isg/me_chess_llvm.h:76287:7: note: 'broadcast_zero_u16' has been explicitly marked deprecated here
#     [[deprecated("Function 'broadcast_zero_u16' is deprecated. Please use the 'broadcast_zero_to_v32uint16' variant instead.")]] inline __attribute__((always_inline)) v32uint16 broadcast_zero_u16(void) __attribute__((overloadable))
#       ^
# In file included from fft_kernel.cc:8:
# In file included from /opt/tools/Vitis/2023.1/aietools/include/aie_api/aie.hpp:111:
# In file included from /opt/tools/Vitis/2023.1/aietools/include/aie_api/detail/linear_approx.hpp:66:
# /opt/tools/Vitis/2023.1/aietools/include/aie_api/detail/aie2/linear_approx.hpp:255:93: warning: 'broadcast_zero_s16' is deprecated: Function 'broadcast_zero_s16' is deprecated. Please use the 'broadcast_zero_to_v32int16' variant instead. [-Wdeprecated-declarations]
#         result  = ::mac_elem_16_2_conf(::set_v32int16(0, input_), ::sel(broadcast_s16(1), ::broadcast_zero_s16(), 0xFFFF0000), result, 0, 0, 0, 1);
#                                                                                             ^
# /opt/tools/Vitis/2023.1/aietools/data/aie_ml/lib/isg/me_chess_llvm.h:76266:7: note: 'broadcast_zero_s16' has been explicitly marked deprecated here
#     [[deprecated("Function 'broadcast_zero_s16' is deprecated. Please use the 'broadcast_zero_to_v32int16' variant instead.")]] inline __attribute__((always_inline)) v32int16 broadcast_zero_s16(void) __attribute__((overloadable))
#       ^
# In file included from fft_kernel.cc:8:
# In file included from /opt/tools/Vitis/2023.1/aietools/include/aie_api/aie.hpp:111:
# In file included from /opt/tools/Vitis/2023.1/aietools/include/aie_api/detail/linear_approx.hpp:66:
# /opt/tools/Vitis/2023.1/aietools/include/aie_api/detail/aie2/linear_approx.hpp:280:46: warning: 'broadcast_zero_s32' is deprecated: Function 'broadcast_zero_s32' is deprecated. Please use the 'broadcast_zero_to_v16int32' variant instead. [-Wdeprecated-declarations]
#             const vector<int32, 16> zero = ::broadcast_zero_s32();
#                                              ^
# /opt/tools/Vitis/2023.1/aietools/data/aie_ml/lib/isg/me_chess_llvm.h:76273:7: note: 'broadcast_zero_s32' has been explicitly marked deprecated here
#     [[deprecated("Function 'broadcast_zero_s32' is deprecated. Please use the 'broadcast_zero_to_v16int32' variant instead.")]] inline __attribute__((always_inline)) v16int32 broadcast_zero_s32(void) __attribute__((overloadable))
#       ^
# In file included from fft_kernel.cc:8:
# In file included from /opt/tools/Vitis/2023.1/aietools/include/aie_api/aie.hpp:111:
# In file included from /opt/tools/Vitis/2023.1/aietools/include/aie_api/detail/linear_approx.hpp:66:
# /opt/tools/Vitis/2023.1/aietools/include/aie_api/detail/aie2/linear_approx.hpp:360:23: warning: 'broadcast_zero_bfloat16' is deprecated: Function 'broadcast_zero_bfloat16' is deprecated. Please use the 'broadcast_zero_to_v32bfloat16' variant instead. [-Wdeprecated-declarations]
#         delay_in_ = ::broadcast_zero_bfloat16();
#                       ^
# /opt/tools/Vitis/2023.1/aietools/data/aie_ml/lib/isg/me_chess_llvm.h:76315:7: note: 'broadcast_zero_bfloat16' has been explicitly marked deprecated here
#     [[deprecated("Function 'broadcast_zero_bfloat16' is deprecated. Please use the 'broadcast_zero_to_v32bfloat16' variant instead.")]] inline __attribute__((always_inline)) v32bfloat16 broadcast_zero_bfloat16(void) __attribute__((overloadable))
#       ^
# In file included from fft_kernel.cc:8:
# In file included from /opt/tools/Vitis/2023.1/aietools/include/aie_api/aie.hpp:9386:
# In file included from /opt/tools/Vitis/2023.1/aietools/include/aie_api/aie_adf.hpp:75:
# In file included from /opt/tools/Vitis/2023.1/aietools/include/aie_api/adf/stream.hpp:54:
# In file included from /opt/tools/Vitis/2023.1/aietools/include/adf.h:7:
# /opt/tools/Vitis/2023.1/aietools/include/adf/intrinsics.h:28:9: warning: 'REL_WRITE' macro redefined [-Wmacro-redefined]
# #define REL_WRITE -1
#         ^
# fft_kernel.cc:6:9: note: previous definition is here
# #define REL_WRITE 0
#         ^
# fft_kernel.cc:20:12: error: no member named 'fft_dit_r2_stage' in namespace 'aie'
#     ::aie::fft_dit_r2_stage(in_buffer, in_buffer2, 16, false, out_buffer);
#     ~~~~~~~^
# 28 warnings and 1 error generated.
# xchesscc Failed Function not implemented
# The Program xchesscc has encountered an unexpected error exiting ... xchesscc Failed Function not implemented
# /opt/tools/Vitis/2023.1/aietools/bin/xchesscc: line 83: kill: (-12085) - No such process
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Cell In[6], line 9
#       6 input_form2 = np.zeros(shape=(1, P), dtype=np.uint64)
#       7 output_form = np.zeros(shape=(1, P), dtype=np.uint64)
# ----> 9 app_builder.build(input_form, input_form2, output_form)
#      11 app = AppRunner('SimpleApplication.xclbin')
#
# File ~/riallto_venv/lib/python3.12/site-packages/npu/build/appbuilder.py:133, in AppBuilder.build(self, debug, mlir, *args)
#     131 self.to_handoff(*args, file=f"{self.name}.json")
#     132 if mlir is None:
# --> 133     self.ab.build(self.name, f"{self.name}.mlir", self.kernels, debug)
#     134 else:
#     135     self.ab.build(self.name, mlir, self.kernels, debug)
#
# File ~/riallto_venv/lib/python3.12/site-packages/npu/build/appxclbinbuilder.py:48, in AppXclbinBuilder.build(self, appname, mlir_file, kernels, debug)
#      28 """Toplevel call to build the xclbin
#      29
#      30 Parameters
#    (...)
#      44
#      45 """
#      46 self._wslcall(f"{wsl_prefix()}bash", [f"{wslpath(self.build_path)}/check_license.sh"])
# ---> 48 self.build_kernels(kernels, debug)
#      49 self.buildlog = os.path.join(self.build_path, "build.log")
#      51 print("Building the xclbin...")
#
# File ~/riallto_venv/lib/python3.12/site-packages/npu/build/appxclbinbuilder.py:66, in AppXclbinBuilder.build_kernels(self, kernels, debug)
#      64 kernel_types = {k.ktype : k for k in kernels if k.ttype == "CT"}
#      65 for _, k in kernel_types.items():
# ---> 66     k.build(debug)
#      67     objpath = wslpath(k.kb.buildobjpath)
#      68     appobjpath =  wslpath(os.path.join(self.build_path, f'{k.ktype}.o'))
#
# File ~/riallto_venv/lib/python3.12/site-packages/npu/build/kernel.py:238, in Kernel.build(self, debug)
#     236 """Build the kernel object file for linking into the complete application."""
#     237 if not os.path.exists(self.kb.buildobjpath):
# --> 238     self.kb.build(debug)
#
# File ~/riallto_venv/lib/python3.12/site-packages/npu/build/kernelbuilder.py:79, in KernelObjectBuilder.build(self, debug)
#      74             for hfile in glob.glob(os.path.join(self.srcpath, extension)):
#      75                 self._wslcall(f"{wsl_prefix()}cp",
#      76                               [f"{wslpath(hfile)}",
#      77                                f"{wslpath(self.build_path)}"], debug)
# ---> 79     self._wslcall(f"{wsl_prefix()}bash", [f"{wslpath(self.build_path)}/kernel_build.sh", f"{self.name}"], debug)
#      80     self._wslcall(f"{wsl_prefix()}cp", [f"{wslpath(self.buildobjpath)}", f"{wslpath(self.prebuilt_objpath)}"], debug)
#      82 self.update_cache_md5()
#
# File ~/riallto_venv/lib/python3.12/site-packages/npu/build/wslbuilder.py:43, in WSLBuilder._wslcall(self, cmd, arglist, debug)
#      41 except subprocess.CalledProcessError as e:
#      42     print(f"ERROR! WSL failed \n\n{e.output.decode()}")
# ---> 43     raise e
#
# File ~/riallto_venv/lib/python3.12/site-packages/npu/build/wslbuilder.py:38, in WSLBuilder._wslcall(self, cmd, arglist, debug)
#      36 cmdlist = cmd.split(" ") + arglist
#      37 try:
# ---> 38     output = subprocess.check_output(cmdlist, stderr=subprocess.STDOUT)
#      39     if debug:
#      40         print(f"{output.decode('UTF-8').rstrip()}")
#
# File /usr/lib/python3.12/subprocess.py:466, in check_output(timeout, *popenargs, **kwargs)
#     463         empty = b''
#     464     kwargs['input'] = empty
# --> 466 return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#     467            **kwargs).stdout
#
# File /usr/lib/python3.12/subprocess.py:571, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     569     retcode = process.poll()
#     570     if check and retcode:
# --> 571         raise CalledProcessError(retcode, process.args,
#     572                                  output=stdout, stderr=stderr)
#     573 return CompletedProcess(process.args, retcode, stdout, stderr)
#
# CalledProcessError: Command '['bash', '/tmp/pnxjyll4pej/build_template/kernel_build.sh', 'fft_kernel']' returned non-zero exit status 255.

# %%
def generate_win_coeffs(M, P, window_fn="hamming"):
    win_coeffs = scipy.signal.get_window(window_fn, P)
    sinc       = scipy.signal.firwin(P, cutoff=1.0/P, window="rectangular")
    win_coeffs *= sinc
    return win_coeffs

# %%
# Generating input data
noise = np.random.normal(loc=0.5, scale=0.1, size=P).astype(np.float32)
samples = np.arange(P)
freq    = 1
amp     = 1
cw_signal = (amp * np.sin(samples * freq))
data = noise + cw_signal
plt.plot(data)
plt.show()
plt.clf()
data = data.astype(dt)

# %%
# Generate window coefficients
win_coeffs = generate_win_coeffs(M, P, "hamming")
pg = np.sum(np.abs(win_coeffs)**2)
win_coeffs /= pg**.5 # Normalize for processing gain
win_coeffs = win_coeffs.astype(np.float32)
plt.plot(win_coeffs)
plt.show()
plt.clf()

# %%
# Generating Twiddle groups
tw_groups = []
for i in 2 ** np.arange(np.log2(P) + 1):
    tw = np.tile(np.exp(-2j*np.pi*np.arange(i)/ i), int(P/i)).astype(dt)
    tw_groups.append(tw)

# %%
d = tw_groups[0]
# extract real part 
x = [ele.real for ele in d] 
# extract imaginary part 
y = [ele.imag for ele in d] 
  
# plot the complex numbers 
plt.scatter(x, y) 
plt.ylabel('Imaginary') 
plt.xlabel('Real') 
plt.show() 
plt.clf()

# %%
# Making app runner and running app
input_data = app.allocate(shape=(1, P), dtype=dt)
input_data2 = app.allocate(shape=(1, P), dtype=dt)
output_data = app.allocate(shape=(1, P), dtype=dt)

input_data[:] = data
input_data.sync_to_npu()
input_data2[:] = tw_groups[0]
input_data2.sync_to_npu()

app.call(input_data, input_data2, output_data)

output_data.sync_from_npu()

# %%
plt.plot(output_data[0])
plt.show()
plt.clf()

# %%
del app
